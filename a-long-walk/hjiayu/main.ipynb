# %%
input1 = []

# %%
f = open('input1.txt')
for line in f:
    l = []
    for i in range(len(line) - 1):
        l.append(line[i])
    input1.append(l)

# %%
tileVisited = input1.copy()

# %%
while True:
# Out:
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ha
# ...
